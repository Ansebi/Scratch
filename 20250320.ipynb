# %%
import pandas as pd

# %%
df = pd.read_clipboard()

# %%
df
# Out:
#                       image_name  psnr_oi_ai  psnr_oi_oo  psnr_ai_ao  \
# 0  0001    51.714214   35.238274   27.515215   13.328210    0.881456
# 1  0002    53.530602   34.199881   28.833095   13.154697    1.139532
# 2  0003    53.135887   33.718651   28.734452   14.747389    1.184537
# 3  0004    52.714989   39.813108   30.449648   15.496181    0.441229
# 4  0005    52.737442   36.155082   27.968661   12.746447    0.939688
# 5  0006    51.692219   38.872837   29.405301   13.514724    0.462121
# 6  0007    52.119308   32.011065   26.894833   13.331461    1.508285
# 7  0008    54.320534   35.124360   28.539012   13.950552    0.819710
# 8  0009    52.633652   35.808416   28.963815   13.605459    1.073901
# 9  0010    53.206612   36.127975   29.583631   14.269848    0.752986
# 10 Average 52.780546   35.706965   28.688766   13.814497    0.920345
#
#                       psnr_aip_aop  bpp_oc bpp_ac          time_taken  \
# ...

# %%
df.to_csv('div2k_logexp.csv', sep=';')
